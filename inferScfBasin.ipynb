# %%
import xarray as xr
import geopandas as gpd
import rioxarray
import pandas as pd
from datetime import date
from matplotlib import pyplot as plt
import numpy as np
import pyproj
import pickle
import matplotlib.dates as mdates

# %%
def reshapeDowy(series):
    tmpList = list()
    for y in years:
        ix = np.logical_and(datesClim >= np.datetime64(date(y,11,1)), datesClim < np.datetime64(date(y+1,7,1))) 
        tmpList.append(series.values[ix])
    df = pd.DataFrame(tmpList).transpose()
    df.columns = years
    return df

# %%
# Select period of interest 
endClimDate = '2021-07-01'
startClimDate = '1991-10-01'
dd = pd.DatetimeIndex([startClimDate, endClimDate]).year.values
years = np.arange(dd[0],dd[1])

# %%
# Lazily load all HS netcdf 
dsFullExtent = None
# correct CRS of UERRA dataset is 
crs = "+proj=lcc +lat_1=40 +lat_0=40 +lon_0=35 +a=6371229 +b=6371229 +units=m +x_0=330000 +y_0=880000"
#dsFullExtent = xr.open_mfdataset('snd_UERRA_MESCAN_SURFEX_1961_2018_alps/snd_UERRA_MESCAN_SURFEX_day_*.nc')
dsFullExtent = xr.open_mfdataset('.\DataExport\Lebanon-Snow-Cover-Data\*.nc')
dsFullExtent.rio.write_crs(crs, inplace=True)
datesSel = dsFullExtent['time'].sel(time=slice(startClimDate, endClimDate)) # exceeds 1984-2014
# reduce UERRA dataset to these dates
dsFullExtentSel = dsFullExtent.sel(time=datesSel)
dsFullExtentSel
# Out:
# <xarray.Dataset>
# Dimensions:      (longitude: 13, latitude: 17, time: 7690)
# Coordinates:
#   * longitude    (longitude) float32 35.25 35.35 35.45 ... 36.25 36.35 36.45
#   * latitude     (latitude) float32 34.6 34.5 34.4 34.3 ... 33.3 33.2 33.1 33.0
#   * time         (time) datetime64[ns] 1993-01-01T10:00:00 ... 2021-07-01T10:...
#     spatial_ref  int32 0
# Data variables:
#     sde          (time, latitude, longitude) float32 dask.array<chunksize=(30, 17, 13), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-03-30 01:06:05 GMT by grib_to_netcdf-2.24.0: /opt/ecmw...

# %%
#sf = gpd.reavaluesile('shp/AlpsCatchmentsEEAlonlat.shp')
sf = gpd.read_file('shp/Lebanonshp/LebanonAoi.shp')
sf.plot();
sf
# Out:
#    AREA  POP2005 FIPS   UN     LON ISO3    LAT  SUBREGION  REGION     NAME  \
# 0  1023   401074   LE  422  35.888  LBN  33.92        145     142  Lebanon
#
#   ISO2                                           geometry
# 0   LB  POLYGON ((35.10083 33.09361, 35.12125 33.11222...

# %%
for ibv in range(0,len(sf)):
    fig = plt.figure()    
    bv = sf.geometry
    dsSel = dsFullExtentSel.rio.clip(bv.geometry.values)
    print(dsSel)
    # plot mean snow depth
    dsSel.sde.mean(dim=('latitude','longitude')).plot()
    plt.title('Mean Era5-Land snow depth - {} Lebanon'.format(""));
# Out:
# <xarray.Dataset>
# Dimensions:      (longitude: 13, latitude: 16, time: 7690)
# Coordinates:
#   * longitude    (longitude) float32 35.25 35.35 35.45 ... 36.25 36.35 36.45
#   * latitude     (latitude) float32 34.6 34.5 34.4 34.3 ... 33.4 33.3 33.2 33.1
#   * time         (time) datetime64[ns] 1993-01-01T10:00:00 ... 2021-07-01T10:...
#     spatial_ref  int32 0
# Data variables:
#     sde          (time, latitude, longitude) float32 dask.array<chunksize=(30, 16, 13), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-03-30 01:06:05 GMT by grib_to_netcdf-2.24.0: /opt/ecmw...

# %%
for ibv in range(0,len(sf)):
    bv = sf.loc[[ibv]]
   # bvname = bv.BASINNAME.values[0]
    dsSel = dsFullExtentSel.rio.clip(bv.geometry.values, bv.crs)
    # Make X array with predictors
    X = dsSel['sde'].values.reshape(datesSel.size,-1)
    # remove nodata [TODO: APPLY MODIS AOI MASK]
    ix = np.all(np.isnan(X),axis=0)
    # This is the array of training data (snow depth of every cell)
    X = X[:,~ix]

    # load model
    f = '{}Scf01July5d'.format("")
    mod = pickle.load( open( 'mod2{}.pickle'.format(f), "rb" ) )
    xmod = mod.predict(X)
    lastPredDate = datesSel[-1]

    # create date and scf arrays from Modis csv
    dfscf = pd.read_csv('Modis/{}.csv'.format(f), index_col=0, decimal='.')
    doy = dfscf.index
    dfdate = pd.DataFrame([pd.to_datetime(doy-1, unit='D', origin=str(y)) for y in dfscf.columns]).transpose()
    dfdate.index = dfscf.index
    dfdate.columns = dfscf.columns
    dates = dfdate.transpose().stack(dropna=False)
    scf = dfscf.transpose().stack(dropna=False)

    # index of modis dates taht will be used to complete the predicted series
    ix = np.logical_and(dates > lastPredDate.values, dates < np.datetime64(endClimDate))

    datesClim = pd.concat([
        pd.Series(datesSel), 
        pd.Series(dates[ix])]
        , axis=0, ignore_index=True)

    scfClim = pd.concat([
        pd.Series(xmod),
        pd.Series(scf[ix])]
        , axis = 0, ignore_index=True)

    # convert dates to millis (POSIX) to match 'system:time_start' in earth engine
    millis = pd.Series(datesClim, name='system:time_start')
    millis = millis.apply(lambda x: x.replace(hour=0).timestamp()*1000 )
    # convert dates at 6:00 to date only
    #dates = pd.Series(datesSel, name='dates').dt.date

    # concat scf
    outdf = pd.concat([millis, pd.Series(scfClim, name='scf')], axis = 1)
    outdf.set_index('system:time_start',inplace=True)
    outdf.to_csv('export/predictedScf_{}.csv'.format(""))

    # reshape to hydro years
    scfClimDowy = reshapeDowy(scfClim)
    datesClimDowy = reshapeDowy(datesClim)
    scfClimDowy.index = datesClimDowy.iloc[0:scfClimDowy.shape[0],0]

    fig = plt.figure(figsize=(12, 5), dpi=100);
    ax1 = fig.subplots(ncols=1)

    ax1.plot(scfClimDowy, color='grey')
    ax1.set_ylabel('Snow cover fraction')
    ax1.set_xlabel('Month')
    ax1.set_title('{} water years from Nov {} to Jul {}'.format(len(years),years[0],years[-1]+1))
    ax1.set_xlim([date(years[0],11,1), date(years[0]+1,7,1)])
    ax1.set_ylim([0,1])
    ax1.xaxis.set_major_locator(mdates.MonthLocator())
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
    fig.suptitle('{} river basin'.format(""));
# Out:
# ---------------------------------------------------------------------------
# NoDataInBounds                            Traceback (most recent call last)
# c:\Users\rami.ismail\Desktop\FYP\Scripts\Modis\ModisExtension\inferScfBasin.ipynb Cell 7 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/rami.ismail/Desktop/FYP/Scripts/Modis/ModisExtension/inferScfBasin.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>  bv = sf.loc[[ibv]]
#       <a href='vscode-notebook-cell:/c%3A/Users/rami.ismail/Desktop/FYP/Scripts/Modis/ModisExtension/inferScfBasin.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> # bvname = bv.BASINNAME.values[0]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rami.ismail/Desktop/FYP/Scripts/Modis/ModisExtension/inferScfBasin.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>  dsSel = dsFullExtentSel.rio.clip(bv.geometry.values, bv.crs)
#       <a href='vscode-notebook-cell:/c%3A/Users/rami.ismail/Desktop/FYP/Scripts/Modis/ModisExtension/inferScfBasin.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>  # Make X array with predictors
#       <a href='vscode-notebook-cell:/c%3A/Users/rami.ismail/Desktop/FYP/Scripts/Modis/ModisExtension/inferScfBasin.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>  X = dsSel['sde'].values.reshape(datesSel.size,-1)
#
# File c:\Python310\lib\site-packages\rioxarray\raster_dataset.py:381, in RasterDataset.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     378 try:
#     379     x_dim, y_dim = _get_spatial_dims(self._obj, var)
#     380     clipped_dataset[var] = (
# --> 381         self._obj[var]
#     382         .rio.set_spatial_dims(x_dim=x_dim, y_dim=y_dim, inplace=True)
#     383         .rio.clip(
#     384             geometries,
#     385             crs=crs,
#     386             all_touched=all_touched,
#     387             drop=drop,
#     388             invert=invert,
#     389             from_disk=from_disk,
#     390         )
#     391     )
#     392 except MissingSpatialDimensionError:
#     393     if len(self._obj[var].dims) >= 2 and not get_option(
#     394         SKIP_MISSING_SPATIAL_DIMS
#     395     ):
#
# File c:\Python310\lib\site-packages\rioxarray\raster_array.py:921, in RasterArray.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     909     cropped_ds = _clip_xarray(
#     910         self._obj,
#     911         geometries=geometries,
#    (...)
#     914         invert=invert,
#     915     )
#     917 if (
#     918     cropped_ds.coords[self.x_dim].size < 1
#     919     or cropped_ds.coords[self.y_dim].size < 1
#     920 ):
# --> 921     raise NoDataInBounds(
#     922         f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     923     )
#     925 # make sure correct attributes preserved & projection added
#     926 _add_attrs_proj(cropped_ds, self._obj)
#
# NoDataInBounds: No data found in bounds. Data variable: sde
